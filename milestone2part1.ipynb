# %%
import csv

# %%
# %env INSTANCE = mysql-final-project
# Out:
# env: INSTANCE=mysql-final-project

# %%
# !mysql < /home/jupyter/create_table.sql

# %%
# !mysql load_testing -e "select count(*) from Person"
# Out:
# +----------+
# | count(*) |
# +----------+
# |        0 |
# +----------+

# %% [markdown]
# ## Our batch size is 5000

# %%
# %%timeit
import mysql.connector

connection = mysql.connector.connect(
  host="10.128.0.3",
  user="root",
  password="12345",
  database="load_testing",
  autocommit=False
)

#

file = open('us-1000000.csv')
csvreader = csv.reader(file)
header = []
header = next(csvreader)
batch = [] 

insert_stmt = (
  "INSERT INTO Person ( first_name, last_name, company, addresss, city, county, state, postal_code, phone_1, phone_2, email, web) "
  "VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s )"
)
counter = 0 
cursor = connection.cursor()

for row in csvreader:
            
            batch.append(row)
            counter += 1
        
            if len(batch) == 5000:
                
                try:
                    cursor.executemany(insert_stmt, batch)
                    connection.commit()
                    print(counter, "Record inserted successfully into Person table")
                    batch = [] 
    
                except mysql.connector.Error as error:
                            print("Failed to insert record into Person table {}".format(error))

                finally:
                    if counter == 1000000:
                        if connection.is_connected():
                                connection.close()
                                print("MySQL connection is closed")
               
file.close()
# Out:
# 5000 Record inserted successfully into Person table
# 10000 Record inserted successfully into Person table
# 15000 Record inserted successfully into Person table
# 20000 Record inserted successfully into Person table
# 25000 Record inserted successfully into Person table
# 30000 Record inserted successfully into Person table
# 35000 Record inserted successfully into Person table
# 40000 Record inserted successfully into Person table
# 45000 Record inserted successfully into Person table
# 50000 Record inserted successfully into Person table
# 55000 Record inserted successfully into Person table
# 60000 Record inserted successfully into Person table
# 65000 Record inserted successfully into Person table
# 70000 Record inserted successfully into Person table
# 75000 Record inserted successfully into Person table
# 80000 Record inserted successfully into Person table
# 85000 Record inserted successfully into Person table
# 90000 Record inserted successfully into Person table
# 95000 Record inserted successfully into Person table
# 100000 Record inserted successfully into Person table
# 105000 Record inserted successfully into Person table
# 110000 Record inserted successfully into Person table
# 115000 Record inserted successfully into Person table
# 120000 Record inserted successfully into Person table
# 125000 Record inserted successfully into Person table
# 130000 Record inserted successfully into Person table
# 135000 Record inserted successfully into Person table
# 140000 Record inserted successfully into Person table
# 145000 Record inserted successfully into Person table
# 150000 Record inserted successfully into Person table
# 155000 Record inserted successfully into Person table
# 160000 Record inserted successfully into Person table
# 165000 Record inserted successfully into Person table
# 170000 Record inserted successfully into Person table
# 175000 Record inserted successfully into Person table
# 180000 Record inserted successfully into Person table
# 185000 Record inserted successfully into Person table
# 190000 Record inserted successfully into Person table
# 195000 Record inserted successfully into Person table
# 200000 Record inserted successfully into Person table
# 205000 Record inserted successfully into Person table
# 210000 Record inserted successfully into Person table
# 215000 Record inserted successfully into Person table
# 220000 Record inserted successfully into Person table
# 225000 Record inserted successfully into Person table
# 230000 Record inserted successfully into Person table
# 235000 Record inserted successfully into Person table
# 240000 Record inserted successfully into Person table
# 245000 Record inserted successfully into Person table
# 250000 Record inserted successfully into Person table
# 255000 Record inserted successfully into Person table
# 260000 Record inserted successfully into Person table
# 265000 Record inserted successfully into Person table
# 270000 Record inserted successfully into Person table
# 275000 Record inserted successfully into Person table
# 280000 Record inserted successfully into Person table
# 285000 Record inserted successfully into Person table
# 290000 Record inserted successfully into Person table
# 295000 Record inserted successfully into Person table
# 300000 Record inserted successfully into Person table
# 305000 Record inserted successfully into Person table
# 310000 Record inserted successfully into Person table
# 315000 Record inserted successfully into Person table
# 320000 Record inserted successfully into Person table
# 325000 Record inserted successfully into Person table
# 330000 Record inserted successfully into Person table
# 335000 Record inserted successfully into Person table
# 340000 Record inserted successfully into Person table
# 345000 Record inserted successfully into Person table
# 350000 Record inserted successfully into Person table
# 355000 Record inserted successfully into Person table
# 360000 Record inserted successfully into Person table
# 365000 Record inserted successfully into Person table
# 370000 Record inserted successfully into Person table
# 375000 Record inserted successfully into Person table
# 380000 Record inserted successfully into Person table
# 385000 Record inserted successfully into Person table
# 390000 Record inserted successfully into Person table
# 395000 Record inserted successfully into Person table
# 400000 Record inserted successfully into Person table
# 405000 Record inserted successfully into Person table
# 410000 Record inserted successfully into Person table
# 415000 Record inserted successfully into Person table
# 420000 Record inserted successfully into Person table
# 425000 Record inserted successfully into Person table
# 430000 Record inserted successfully into Person table
# 435000 Record inserted successfully into Person table
# 440000 Record inserted successfully into Person table
# 445000 Record inserted successfully into Person table
# 450000 Record inserted successfully into Person table
# 455000 Record inserted successfully into Person table
# 460000 Record inserted successfully into Person table
# 465000 Record inserted successfully into Person table
# 470000 Record inserted successfully into Person table
# 475000 Record inserted successfully into Person table
# 480000 Record inserted successfully into Person table
# 485000 Record inserted successfully into Person table
# 490000 Record inserted successfully into Person table
# 495000 Record inserted successfully into Person table
# 500000 Record inserted successfully into Person table
# 505000 Record inserted successfully into Person table
# 510000 Record inserted successfully into Person table
# 515000 Record inserted successfully into Person table
# 520000 Record inserted successfully into Person table
# 525000 Record inserted successfully into Person table
# 530000 Record inserted successfully into Person table
# 535000 Record inserted successfully into Person table
# 540000 Record inserted successfully into Person table
# 545000 Record inserted successfully into Person table
# 550000 Record inserted successfully into Person table
# 555000 Record inserted successfully into Person table
# 560000 Record inserted successfully into Person table
# 565000 Record inserted successfully into Person table
# 570000 Record inserted successfully into Person table
# 575000 Record inserted successfully into Person table
# 580000 Record inserted successfully into Person table
# 585000 Record inserted successfully into Person table
# 590000 Record inserted successfully into Person table
# 595000 Record inserted successfully into Person table
# 600000 Record inserted successfully into Person table
# 605000 Record inserted successfully into Person table
# 610000 Record inserted successfully into Person table
# 615000 Record inserted successfully into Person table
# 620000 Record inserted successfully into Person table
# 625000 Record inserted successfully into Person table
# 630000 Record inserted successfully into Person table
# 635000 Record inserted successfully into Person table
# 640000 Record inserted successfully into Person table
# 645000 Record inserted successfully into Person table
# 650000 Record inserted successfully into Person table
# 655000 Record inserted successfully into Person table
# 660000 Record inserted successfully into Person table
# 665000 Record inserted successfully into Person table
# 670000 Record inserted successfully into Person table
# 675000 Record inserted successfully into Person table
# 680000 Record inserted successfully into Person table
# 685000 Record inserted successfully into Person table
# 690000 Record inserted successfully into Person table
# 695000 Record inserted successfully into Person table
# 700000 Record inserted successfully into Person table
# 705000 Record inserted successfully into Person table
# 710000 Record inserted successfully into Person table
# 715000 Record inserted successfully into Person table
# 720000 Record inserted successfully into Person table
# 725000 Record inserted successfully into Person table
# 730000 Record inserted successfully into Person table
# 735000 Record inserted successfully into Person table
# 740000 Record inserted successfully into Person table
# 745000 Record inserted successfully into Person table
# 750000 Record inserted successfully into Person table
# 755000 Record inserted successfully into Person table
# 760000 Record inserted successfully into Person table
# 765000 Record inserted successfully into Person table
# 770000 Record inserted successfully into Person table
# 775000 Record inserted successfully into Person table
# 780000 Record inserted successfully into Person table
# 785000 Record inserted successfully into Person table
# 790000 Record inserted successfully into Person table
# 795000 Record inserted successfully into Person table
# 800000 Record inserted successfully into Person table
# 805000 Record inserted successfully into Person table
# 810000 Record inserted successfully into Person table
# 815000 Record inserted successfully into Person table
# 820000 Record inserted successfully into Person table
# 825000 Record inserted successfully into Person table
# 830000 Record inserted successfully into Person table
# 835000 Record inserted successfully into Person table
# 840000 Record inserted successfully into Person table
# 845000 Record inserted successfully into Person table
# 850000 Record inserted successfully into Person table
# 855000 Record inserted successfully into Person table
# 860000 Record inserted successfully into Person table
# 865000 Record inserted successfully into Person table
# 870000 Record inserted successfully into Person table
# 875000 Record inserted successfully into Person table
# 880000 Record inserted successfully into Person table
# 885000 Record inserted successfully into Person table
# 890000 Record inserted successfully into Person table
# 895000 Record inserted successfully into Person table
# 900000 Record inserted successfully into Person table
# 905000 Record inserted successfully into Person table
# 910000 Record inserted successfully into Person table
# 915000 Record inserted successfully into Person table
# 920000 Record inserted successfully into Person table
# 925000 Record inserted successfully into Person table
# 930000 Record inserted successfully into Person table
# 935000 Record inserted successfully into Person table
# 940000 Record inserted successfully into Person table
# 945000 Record inserted successfully into Person table
# 950000 Record inserted successfully into Person table
# 955000 Record inserted successfully into Person table
# 960000 Record inserted successfully into Person table
# 965000 Record inserted successfully into Person table
# 970000 Record inserted successfully into Person table
# 975000 Record inserted successfully into Person table
# 980000 Record inserted successfully into Person table
# 985000 Record inserted successfully into Person table
# 990000 Record inserted successfully into Person table
# 995000 Record inserted successfully into Person table
# 1000000 Record inserted successfully into Person table
# MySQL connection is closed
# 5000 Record inserted successfully into Person table
# 10000 Record inserted successfully into Person table
# 15000 Record inserted successfully into Person table
# 20000 Record inserted successfully into Person table
# 25000 Record inserted successfully into Person table
# 30000 Record inserted successfully into Person table
# 35000 Record inserted successfully into Person table
# 40000 Record inserted successfully into Person table
# 45000 Record inserted successfully into Person table
# 50000 Record inserted successfully into Person table
# 55000 Record inserted successfully into Person table
# 60000 Record inserted successfully into Person table
# 65000 Record inserted successfully into Person table
# 70000 Record inserted successfully into Person table
# 75000 Record inserted successfully into Person table
# 80000 Record inserted successfully into Person table
# 85000 Record inserted successfully into Person table
# 90000 Record inserted successfully into Person table
# 95000 Record inserted successfully into Person table
# 100000 Record inserted successfully into Person table
# 105000 Record inserted successfully into Person table
# 110000 Record inserted successfully into Person table
# 115000 Record inserted successfully into Person table
# 120000 Record inserted successfully into Person table
# 125000 Record inserted successfully into Person table
# 130000 Record inserted successfully into Person table
# 135000 Record inserted successfully into Person table
# 140000 Record inserted successfully into Person table
# 145000 Record inserted successfully into Person table
# 150000 Record inserted successfully into Person table
# 155000 Record inserted successfully into Person table
# 160000 Record inserted successfully into Person table
# 165000 Record inserted successfully into Person table
# 170000 Record inserted successfully into Person table
# 175000 Record inserted successfully into Person table
# 180000 Record inserted successfully into Person table
# 185000 Record inserted successfully into Person table
# 190000 Record inserted successfully into Person table
# 195000 Record inserted successfully into Person table
# 200000 Record inserted successfully into Person table
# 205000 Record inserted successfully into Person table
# 210000 Record inserted successfully into Person table
# 215000 Record inserted successfully into Person table
# 220000 Record inserted successfully into Person table
# 225000 Record inserted successfully into Person table
# 230000 Record inserted successfully into Person table
# 235000 Record inserted successfully into Person table
# 240000 Record inserted successfully into Person table
# 245000 Record inserted successfully into Person table
# 250000 Record inserted successfully into Person table
# 255000 Record inserted successfully into Person table
# 260000 Record inserted successfully into Person table
# 265000 Record inserted successfully into Person table
# 270000 Record inserted successfully into Person table
# 275000 Record inserted successfully into Person table
# 280000 Record inserted successfully into Person table
# 285000 Record inserted successfully into Person table
# 290000 Record inserted successfully into Person table
# 295000 Record inserted successfully into Person table
# 300000 Record inserted successfully into Person table
# 305000 Record inserted successfully into Person table
# 310000 Record inserted successfully into Person table
# 315000 Record inserted successfully into Person table
# 320000 Record inserted successfully into Person table
# 325000 Record inserted successfully into Person table
# 330000 Record inserted successfully into Person table
# 335000 Record inserted successfully into Person table
# 340000 Record inserted successfully into Person table
# 345000 Record inserted successfully into Person table
# 350000 Record inserted successfully into Person table
# 355000 Record inserted successfully into Person table
# 360000 Record inserted successfully into Person table
# 365000 Record inserted successfully into Person table
# 370000 Record inserted successfully into Person table
# 375000 Record inserted successfully into Person table
# 380000 Record inserted successfully into Person table
# 385000 Record inserted successfully into Person table
# 390000 Record inserted successfully into Person table
# 395000 Record inserted successfully into Person table
# 400000 Record inserted successfully into Person table
# 405000 Record inserted successfully into Person table
# 410000 Record inserted successfully into Person table
# 415000 Record inserted successfully into Person table
# 420000 Record inserted successfully into Person table
# 425000 Record inserted successfully into Person table
# 430000 Record inserted successfully into Person table
# 435000 Record inserted successfully into Person table
# 440000 Record inserted successfully into Person table
# 445000 Record inserted successfully into Person table
# 450000 Record inserted successfully into Person table
# 455000 Record inserted successfully into Person table
# 460000 Record inserted successfully into Person table
# 465000 Record inserted successfully into Person table
# 470000 Record inserted successfully into Person table
# 475000 Record inserted successfully into Person table
# 480000 Record inserted successfully into Person table
# 485000 Record inserted successfully into Person table
# 490000 Record inserted successfully into Person table
# 495000 Record inserted successfully into Person table
# 500000 Record inserted successfully into Person table
# 505000 Record inserted successfully into Person table
# 510000 Record inserted successfully into Person table
# 515000 Record inserted successfully into Person table
# 520000 Record inserted successfully into Person table
# 525000 Record inserted successfully into Person table
# 530000 Record inserted successfully into Person table
# 535000 Record inserted successfully into Person table
# 540000 Record inserted successfully into Person table
# 545000 Record inserted successfully into Person table
# 550000 Record inserted successfully into Person table
# 555000 Record inserted successfully into Person table
# 560000 Record inserted successfully into Person table
# 565000 Record inserted successfully into Person table
# 570000 Record inserted successfully into Person table
# 575000 Record inserted successfully into Person table
# 580000 Record inserted successfully into Person table
# 585000 Record inserted successfully into Person table
# 590000 Record inserted successfully into Person table
# 595000 Record inserted successfully into Person table
# 600000 Record inserted successfully into Person table
# 605000 Record inserted successfully into Person table
# 610000 Record inserted successfully into Person table
# 615000 Record inserted successfully into Person table
# 620000 Record inserted successfully into Person table
# 625000 Record inserted successfully into Person table
# 630000 Record inserted successfully into Person table
# 635000 Record inserted successfully into Person table
# 640000 Record inserted successfully into Person table
# 645000 Record inserted successfully into Person table
# 650000 Record inserted successfully into Person table
# 655000 Record inserted successfully into Person table
# 660000 Record inserted successfully into Person table
# 665000 Record inserted successfully into Person table
# 670000 Record inserted successfully into Person table
# 675000 Record inserted successfully into Person table
# 680000 Record inserted successfully into Person table
# 685000 Record inserted successfully into Person table
# 690000 Record inserted successfully into Person table
# 695000 Record inserted successfully into Person table
# 700000 Record inserted successfully into Person table
# 705000 Record inserted successfully into Person table
# 710000 Record inserted successfully into Person table
# 715000 Record inserted successfully into Person table
# 720000 Record inserted successfully into Person table
# 725000 Record inserted successfully into Person table
# 730000 Record inserted successfully into Person table
# 735000 Record inserted successfully into Person table
# 740000 Record inserted successfully into Person table
# 745000 Record inserted successfully into Person table
# 750000 Record inserted successfully into Person table
# 755000 Record inserted successfully into Person table
# 760000 Record inserted successfully into Person table
# 765000 Record inserted successfully into Person table
# 770000 Record inserted successfully into Person table
# 775000 Record inserted successfully into Person table
# 780000 Record inserted successfully into Person table
# 785000 Record inserted successfully into Person table
# 790000 Record inserted successfully into Person table
# 795000 Record inserted successfully into Person table
# 800000 Record inserted successfully into Person table
# 805000 Record inserted successfully into Person table
# 810000 Record inserted successfully into Person table
# 815000 Record inserted successfully into Person table
# 820000 Record inserted successfully into Person table
# 825000 Record inserted successfully into Person table
# 830000 Record inserted successfully into Person table
# 835000 Record inserted successfully into Person table
# 840000 Record inserted successfully into Person table
# 845000 Record inserted successfully into Person table
# 850000 Record inserted successfully into Person table
# 855000 Record inserted successfully into Person table
# 860000 Record inserted successfully into Person table
# 865000 Record inserted successfully into Person table
# 870000 Record inserted successfully into Person table
# 875000 Record inserted successfully into Person table
# 880000 Record inserted successfully into Person table
# 885000 Record inserted successfully into Person table
# 890000 Record inserted successfully into Person table
# 895000 Record inserted successfully into Person table
# 900000 Record inserted successfully into Person table
# 905000 Record inserted successfully into Person table
# 910000 Record inserted successfully into Person table
# 915000 Record inserted successfully into Person table
# 920000 Record inserted successfully into Person table
# 925000 Record inserted successfully into Person table
# 930000 Record inserted successfully into Person table
# 935000 Record inserted successfully into Person table
# 940000 Record inserted successfully into Person table
# 945000 Record inserted successfully into Person table
# 950000 Record inserted successfully into Person table
# 955000 Record inserted successfully into Person table
# 960000 Record inserted successfully into Person table
# 965000 Record inserted successfully into Person table
# 970000 Record inserted successfully into Person table
# 975000 Record inserted successfully into Person table
# 980000 Record inserted successfully into Person table
# 985000 Record inserted successfully into Person table
# 990000 Record inserted successfully into Person table
# 995000 Record inserted successfully into Person table
# 1000000 Record inserted successfully into Person table
# MySQL connection is closed
# 5000 Record inserted successfully into Person table
# 10000 Record inserted successfully into Person table
# 15000 Record inserted successfully into Person table
# 20000 Record inserted successfully into Person table
# 25000 Record inserted successfully into Person table
# 30000 Record inserted successfully into Person table
# 35000 Record inserted successfully into Person table
# 40000 Record inserted successfully into Person table
# 45000 Record inserted successfully into Person table
# 50000 Record inserted successfully into Person table
# 55000 Record inserted successfully into Person table
# 60000 Record inserted successfully into Person table
# 65000 Record inserted successfully into Person table
# 70000 Record inserted successfully into Person table
# 75000 Record inserted successfully into Person table
# 80000 Record inserted successfully into Person table
# 85000 Record inserted successfully into Person table
# 90000 Record inserted successfully into Person table
# 95000 Record inserted successfully into Person table
# 100000 Record inserted successfully into Person table
# 105000 Record inserted successfully into Person table
# 110000 Record inserted successfully into Person table
# 115000 Record inserted successfully into Person table
# 120000 Record inserted successfully into Person table
# 125000 Record inserted successfully into Person table
# 130000 Record inserted successfully into Person table
# 135000 Record inserted successfully into Person table
# 140000 Record inserted successfully into Person table
# 145000 Record inserted successfully into Person table
# 150000 Record inserted successfully into Person table
# 155000 Record inserted successfully into Person table
# 160000 Record inserted successfully into Person table
# 165000 Record inserted successfully into Person table
# 170000 Record inserted successfully into Person table
# 175000 Record inserted successfully into Person table
# 180000 Record inserted successfully into Person table
# 185000 Record inserted successfully into Person table
# 190000 Record inserted successfully into Person table
# 195000 Record inserted successfully into Person table
# 200000 Record inserted successfully into Person table
# 205000 Record inserted successfully into Person table
# 210000 Record inserted successfully into Person table
# 215000 Record inserted successfully into Person table
# 220000 Record inserted successfully into Person table
# 225000 Record inserted successfully into Person table
# 230000 Record inserted successfully into Person table
# 235000 Record inserted successfully into Person table
# 240000 Record inserted successfully into Person table
# 245000 Record inserted successfully into Person table
# 250000 Record inserted successfully into Person table
# 255000 Record inserted successfully into Person table
# 260000 Record inserted successfully into Person table
# 265000 Record inserted successfully into Person table
# 270000 Record inserted successfully into Person table
# 275000 Record inserted successfully into Person table
# 280000 Record inserted successfully into Person table
# 285000 Record inserted successfully into Person table
# 290000 Record inserted successfully into Person table
# 295000 Record inserted successfully into Person table
# 300000 Record inserted successfully into Person table
# 305000 Record inserted successfully into Person table
# 310000 Record inserted successfully into Person table
# 315000 Record inserted successfully into Person table
# 320000 Record inserted successfully into Person table
# 325000 Record inserted successfully into Person table
# 330000 Record inserted successfully into Person table
# 335000 Record inserted successfully into Person table
# 340000 Record inserted successfully into Person table
# 345000 Record inserted successfully into Person table
# 350000 Record inserted successfully into Person table
# 355000 Record inserted successfully into Person table
# 360000 Record inserted successfully into Person table
# 365000 Record inserted successfully into Person table
# 370000 Record inserted successfully into Person table
# 375000 Record inserted successfully into Person table
# 380000 Record inserted successfully into Person table
# 385000 Record inserted successfully into Person table
# 390000 Record inserted successfully into Person table
# 395000 Record inserted successfully into Person table
# 400000 Record inserted successfully into Person table
# 405000 Record inserted successfully into Person table
# 410000 Record inserted successfully into Person table
# 415000 Record inserted successfully into Person table
# 420000 Record inserted successfully into Person table
# 425000 Record inserted successfully into Person table
# 430000 Record inserted successfully into Person table
# 435000 Record inserted successfully into Person table
# 440000 Record inserted successfully into Person table
# 445000 Record inserted successfully into Person table
# 450000 Record inserted successfully into Person table
# 455000 Record inserted successfully into Person table
# 460000 Record inserted successfully into Person table
# 465000 Record inserted successfully into Person table
# 470000 Record inserted successfully into Person table
# 475000 Record inserted successfully into Person table
# 480000 Record inserted successfully into Person table
# 485000 Record inserted successfully into Person table
# 490000 Record inserted successfully into Person table
# 495000 Record inserted successfully into Person table
# 500000 Record inserted successfully into Person table
# 505000 Record inserted successfully into Person table
# 510000 Record inserted successfully into Person table
# 515000 Record inserted successfully into Person table
# 520000 Record inserted successfully into Person table
# 525000 Record inserted successfully into Person table
# 530000 Record inserted successfully into Person table
# 535000 Record inserted successfully into Person table
# 540000 Record inserted successfully into Person table
# 545000 Record inserted successfully into Person table
# 550000 Record inserted successfully into Person table
# 555000 Record inserted successfully into Person table
# 560000 Record inserted successfully into Person table
# 565000 Record inserted successfully into Person table
# 570000 Record inserted successfully into Person table
# 575000 Record inserted successfully into Person table
# 580000 Record inserted successfully into Person table
# 585000 Record inserted successfully into Person table
# 590000 Record inserted successfully into Person table
# 595000 Record inserted successfully into Person table
# 600000 Record inserted successfully into Person table
# 605000 Record inserted successfully into Person table
# 610000 Record inserted successfully into Person table
# 615000 Record inserted successfully into Person table
# 620000 Record inserted successfully into Person table
# 625000 Record inserted successfully into Person table
# 630000 Record inserted successfully into Person table
# 635000 Record inserted successfully into Person table
# 640000 Record inserted successfully into Person table
# 645000 Record inserted successfully into Person table
# 650000 Record inserted successfully into Person table
# 655000 Record inserted successfully into Person table
# 660000 Record inserted successfully into Person table
# 665000 Record inserted successfully into Person table
# 670000 Record inserted successfully into Person table
# 675000 Record inserted successfully into Person table
# 680000 Record inserted successfully into Person table
# 685000 Record inserted successfully into Person table
# 690000 Record inserted successfully into Person table
# 695000 Record inserted successfully into Person table
# 700000 Record inserted successfully into Person table
# 705000 Record inserted successfully into Person table
# 710000 Record inserted successfully into Person table
# 715000 Record inserted successfully into Person table
# 720000 Record inserted successfully into Person table
# 725000 Record inserted successfully into Person table
# 730000 Record inserted successfully into Person table
# 735000 Record inserted successfully into Person table
# 740000 Record inserted successfully into Person table
# 745000 Record inserted successfully into Person table
# 750000 Record inserted successfully into Person table
# 755000 Record inserted successfully into Person table
# 760000 Record inserted successfully into Person table
# 765000 Record inserted successfully into Person table
# 770000 Record inserted successfully into Person table
# 775000 Record inserted successfully into Person table
# 780000 Record inserted successfully into Person table
# 785000 Record inserted successfully into Person table
# 790000 Record inserted successfully into Person table
# 795000 Record inserted successfully into Person table
# 800000 Record inserted successfully into Person table
# 805000 Record inserted successfully into Person table
# 810000 Record inserted successfully into Person table
# 815000 Record inserted successfully into Person table
# 820000 Record inserted successfully into Person table
# 825000 Record inserted successfully into Person table
# 830000 Record inserted successfully into Person table
# 835000 Record inserted successfully into Person table
# 840000 Record inserted successfully into Person table
# 845000 Record inserted successfully into Person table
# 850000 Record inserted successfully into Person table
# 855000 Record inserted successfully into Person table
# 860000 Record inserted successfully into Person table
# 865000 Record inserted successfully into Person table
# 870000 Record inserted successfully into Person table
# 875000 Record inserted successfully into Person table
# 880000 Record inserted successfully into Person table
# 885000 Record inserted successfully into Person table
# 890000 Record inserted successfully into Person table
# 895000 Record inserted successfully into Person table
# 900000 Record inserted successfully into Person table
# 905000 Record inserted successfully into Person table
# 910000 Record inserted successfully into Person table
# 915000 Record inserted successfully into Person table
# 920000 Record inserted successfully into Person table
# 925000 Record inserted successfully into Person table
# 930000 Record inserted successfully into Person table
# 935000 Record inserted successfully into Person table
# 940000 Record inserted successfully into Person table
# 945000 Record inserted successfully into Person table
# 950000 Record inserted successfully into Person table
# 955000 Record inserted successfully into Person table
# 960000 Record inserted successfully into Person table
# 965000 Record inserted successfully into Person table
# 970000 Record inserted successfully into Person table
# 975000 Record inserted successfully into Person table
# 980000 Record inserted successfully into Person table
# 985000 Record inserted successfully into Person table
# 990000 Record inserted successfully into Person table
# 995000 Record inserted successfully into Person table
# 1000000 Record inserted successfully into Person table
# MySQL connection is closed
# 5000 Record inserted successfully into Person table
# 10000 Record inserted successfully into Person table
# 15000 Record inserted successfully into Person table
# 20000 Record inserted successfully into Person table
# 25000 Record inserted successfully into Person table
# 30000 Record inserted successfully into Person table
# 35000 Record inserted successfully into Person table
# 40000 Record inserted successfully into Person table
# 45000 Record inserted successfully into Person table
# 50000 Record inserted successfully into Person table
# 55000 Record inserted successfully into Person table
# 60000 Record inserted successfully into Person table
# 65000 Record inserted successfully into Person table
# 70000 Record inserted successfully into Person table
# 75000 Record inserted successfully into Person table
# 80000 Record inserted successfully into Person table
# 85000 Record inserted successfully into Person table
# 90000 Record inserted successfully into Person table
# 95000 Record inserted successfully into Person table
# 100000 Record inserted successfully into Person table
# 105000 Record inserted successfully into Person table
# 110000 Record inserted successfully into Person table
# 115000 Record inserted successfully into Person table
# 120000 Record inserted successfully into Person table
# 125000 Record inserted successfully into Person table
# 130000 Record inserted successfully into Person table
# 135000 Record inserted successfully into Person table
# 140000 Record inserted successfully into Person table
# 145000 Record inserted successfully into Person table
# 150000 Record inserted successfully into Person table
# 155000 Record inserted successfully into Person table
# 160000 Record inserted successfully into Person table
# 165000 Record inserted successfully into Person table
# 170000 Record inserted successfully into Person table
# 175000 Record inserted successfully into Person table
# 180000 Record inserted successfully into Person table
# 185000 Record inserted successfully into Person table
# 190000 Record inserted successfully into Person table
# 195000 Record inserted successfully into Person table
# 200000 Record inserted successfully into Person table
# 205000 Record inserted successfully into Person table
# 210000 Record inserted successfully into Person table
# 215000 Record inserted successfully into Person table
# 220000 Record inserted successfully into Person table
# 225000 Record inserted successfully into Person table
# 230000 Record inserted successfully into Person table
# 235000 Record inserted successfully into Person table
# 240000 Record inserted successfully into Person table
# 245000 Record inserted successfully into Person table
# 250000 Record inserted successfully into Person table
# 255000 Record inserted successfully into Person table
# 260000 Record inserted successfully into Person table
# 265000 Record inserted successfully into Person table
# 270000 Record inserted successfully into Person table
# 275000 Record inserted successfully into Person table
# 280000 Record inserted successfully into Person table
# 285000 Record inserted successfully into Person table
# 290000 Record inserted successfully into Person table
# 295000 Record inserted successfully into Person table
# 300000 Record inserted successfully into Person table
# 305000 Record inserted successfully into Person table
# 310000 Record inserted successfully into Person table
# 315000 Record inserted successfully into Person table
# 320000 Record inserted successfully into Person table
# 325000 Record inserted successfully into Person table
# 330000 Record inserted successfully into Person table
# 335000 Record inserted successfully into Person table
# 340000 Record inserted successfully into Person table
# 345000 Record inserted successfully into Person table
# 350000 Record inserted successfully into Person table
# 355000 Record inserted successfully into Person table
# 360000 Record inserted successfully into Person table
# 365000 Record inserted successfully into Person table
# 370000 Record inserted successfully into Person table
# 375000 Record inserted successfully into Person table
# 380000 Record inserted successfully into Person table
# 385000 Record inserted successfully into Person table
# 390000 Record inserted successfully into Person table
# 395000 Record inserted successfully into Person table
# 400000 Record inserted successfully into Person table
# 405000 Record inserted successfully into Person table
# 410000 Record inserted successfully into Person table
# 415000 Record inserted successfully into Person table
# 420000 Record inserted successfully into Person table
# 425000 Record inserted successfully into Person table
# 430000 Record inserted successfully into Person table
# 435000 Record inserted successfully into Person table
# 440000 Record inserted successfully into Person table
# 445000 Record inserted successfully into Person table
# 450000 Record inserted successfully into Person table
# 455000 Record inserted successfully into Person table
# 460000 Record inserted successfully into Person table
# 465000 Record inserted successfully into Person table
# 470000 Record inserted successfully into Person table
# 475000 Record inserted successfully into Person table
# 480000 Record inserted successfully into Person table
# 485000 Record inserted successfully into Person table
# 490000 Record inserted successfully into Person table
# 495000 Record inserted successfully into Person table
# 500000 Record inserted successfully into Person table
# 505000 Record inserted successfully into Person table
# 510000 Record inserted successfully into Person table
# 515000 Record inserted successfully into Person table
# 520000 Record inserted successfully into Person table
# 525000 Record inserted successfully into Person table
# 530000 Record inserted successfully into Person table
# 535000 Record inserted successfully into Person table
# 540000 Record inserted successfully into Person table
# 545000 Record inserted successfully into Person table
# 550000 Record inserted successfully into Person table
# 555000 Record inserted successfully into Person table
# 560000 Record inserted successfully into Person table
# 565000 Record inserted successfully into Person table
# 570000 Record inserted successfully into Person table
# 575000 Record inserted successfully into Person table
# 580000 Record inserted successfully into Person table
# 585000 Record inserted successfully into Person table
# 590000 Record inserted successfully into Person table
# 595000 Record inserted successfully into Person table
# 600000 Record inserted successfully into Person table
# 605000 Record inserted successfully into Person table
# 610000 Record inserted successfully into Person table
# 615000 Record inserted successfully into Person table
# 620000 Record inserted successfully into Person table
# 625000 Record inserted successfully into Person table
# 630000 Record inserted successfully into Person table
# 635000 Record inserted successfully into Person table
# 640000 Record inserted successfully into Person table
# 645000 Record inserted successfully into Person table
# 650000 Record inserted successfully into Person table
# 655000 Record inserted successfully into Person table
# 660000 Record inserted successfully into Person table
# 665000 Record inserted successfully into Person table
# 670000 Record inserted successfully into Person table
# 675000 Record inserted successfully into Person table
# 680000 Record inserted successfully into Person table
# 685000 Record inserted successfully into Person table
# 690000 Record inserted successfully into Person table
# 695000 Record inserted successfully into Person table
# 700000 Record inserted successfully into Person table
# 705000 Record inserted successfully into Person table
# 710000 Record inserted successfully into Person table
# 715000 Record inserted successfully into Person table
# 720000 Record inserted successfully into Person table
# 725000 Record inserted successfully into Person table
# 730000 Record inserted successfully into Person table
# 735000 Record inserted successfully into Person table
# 740000 Record inserted successfully into Person table
# 745000 Record inserted successfully into Person table
# 750000 Record inserted successfully into Person table
# 755000 Record inserted successfully into Person table
# 760000 Record inserted successfully into Person table
# 765000 Record inserted successfully into Person table
# 770000 Record inserted successfully into Person table
# 775000 Record inserted successfully into Person table
# 780000 Record inserted successfully into Person table
# 785000 Record inserted successfully into Person table
# 790000 Record inserted successfully into Person table
# 795000 Record inserted successfully into Person table
# 800000 Record inserted successfully into Person table
# 805000 Record inserted successfully into Person table
# 810000 Record inserted successfully into Person table
# 815000 Record inserted successfully into Person table
# 820000 Record inserted successfully into Person table
# 825000 Record inserted successfully into Person table
# 830000 Record inserted successfully into Person table
# 835000 Record inserted successfully into Person table
# 840000 Record inserted successfully into Person table
# 845000 Record inserted successfully into Person table
# 850000 Record inserted successfully into Person table
# 855000 Record inserted successfully into Person table
# 860000 Record inserted successfully into Person table
# 865000 Record inserted successfully into Person table
# 870000 Record inserted successfully into Person table
# 875000 Record inserted successfully into Person table
# 880000 Record inserted successfully into Person table
# 885000 Record inserted successfully into Person table
# 890000 Record inserted successfully into Person table
# 895000 Record inserted successfully into Person table
# 900000 Record inserted successfully into Person table
# 905000 Record inserted successfully into Person table
# 910000 Record inserted successfully into Person table
# 915000 Record inserted successfully into Person table
# 920000 Record inserted successfully into Person table
# 925000 Record inserted successfully into Person table
# 930000 Record inserted successfully into Person table
# 935000 Record inserted successfully into Person table
# 940000 Record inserted successfully into Person table
# 945000 Record inserted successfully into Person table
# 950000 Record inserted successfully into Person table
# 955000 Record inserted successfully into Person table
# 960000 Record inserted successfully into Person table
# 965000 Record inserted successfully into Person table
# 970000 Record inserted successfully into Person table
# 975000 Record inserted successfully into Person table
# 980000 Record inserted successfully into Person table
# 985000 Record inserted successfully into Person table
# 990000 Record inserted successfully into Person table
# 995000 Record inserted successfully into Person table
# 1000000 Record inserted successfully into Person table
# MySQL connection is closed
# 5000 Record inserted successfully into Person table
# 10000 Record inserted successfully into Person table
# 15000 Record inserted successfully into Person table
# 20000 Record inserted successfully into Person table
# 25000 Record inserted successfully into Person table
# 30000 Record inserted successfully into Person table
# 35000 Record inserted successfully into Person table
# 40000 Record inserted successfully into Person table
# 45000 Record inserted successfully into Person table
# 50000 Record inserted successfully into Person table
# 55000 Record inserted successfully into Person table
# 60000 Record inserted successfully into Person table
# 65000 Record inserted successfully into Person table
# 70000 Record inserted successfully into Person table
# 75000 Record inserted successfully into Person table
# 80000 Record inserted successfully into Person table
# 85000 Record inserted successfully into Person table
# 90000 Record inserted successfully into Person table
# 95000 Record inserted successfully into Person table
# 100000 Record inserted successfully into Person table
# 105000 Record inserted successfully into Person table
# 110000 Record inserted successfully into Person table
# 115000 Record inserted successfully into Person table
# 120000 Record inserted successfully into Person table
# 125000 Record inserted successfully into Person table
# 130000 Record inserted successfully into Person table
# 135000 Record inserted successfully into Person table
# 140000 Record inserted successfully into Person table
# 145000 Record inserted successfully into Person table
# 150000 Record inserted successfully into Person table
# 155000 Record inserted successfully into Person table
# 160000 Record inserted successfully into Person table
# 165000 Record inserted successfully into Person table
# 170000 Record inserted successfully into Person table
# 175000 Record inserted successfully into Person table
# 180000 Record inserted successfully into Person table
# 185000 Record inserted successfully into Person table
# 190000 Record inserted successfully into Person table
# 195000 Record inserted successfully into Person table
# 200000 Record inserted successfully into Person table
# 205000 Record inserted successfully into Person table
# 210000 Record inserted successfully into Person table
# 215000 Record inserted successfully into Person table
# 220000 Record inserted successfully into Person table
# 225000 Record inserted successfully into Person table
# 230000 Record inserted successfully into Person table
# 235000 Record inserted successfully into Person table
# 240000 Record inserted successfully into Person table
# 245000 Record inserted successfully into Person table
# 250000 Record inserted successfully into Person table
# 255000 Record inserted successfully into Person table
# 260000 Record inserted successfully into Person table
# 265000 Record inserted successfully into Person table
# 270000 Record inserted successfully into Person table
# 275000 Record inserted successfully into Person table
# 280000 Record inserted successfully into Person table
# 285000 Record inserted successfully into Person table
# 290000 Record inserted successfully into Person table
# 295000 Record inserted successfully into Person table
# 300000 Record inserted successfully into Person table
# 305000 Record inserted successfully into Person table
# 310000 Record inserted successfully into Person table
# 315000 Record inserted successfully into Person table
# 320000 Record inserted successfully into Person table
# 325000 Record inserted successfully into Person table
# 330000 Record inserted successfully into Person table
# 335000 Record inserted successfully into Person table
# 340000 Record inserted successfully into Person table
# 345000 Record inserted successfully into Person table
# 350000 Record inserted successfully into Person table
# 355000 Record inserted successfully into Person table
# 360000 Record inserted successfully into Person table
# 365000 Record inserted successfully into Person table
# 370000 Record inserted successfully into Person table
# 375000 Record inserted successfully into Person table
# 380000 Record inserted successfully into Person table
# 385000 Record inserted successfully into Person table
# 390000 Record inserted successfully into Person table
# 395000 Record inserted successfully into Person table
# 400000 Record inserted successfully into Person table
# 405000 Record inserted successfully into Person table
# 410000 Record inserted successfully into Person table
# 415000 Record inserted successfully into Person table
# 420000 Record inserted successfully into Person table
# 425000 Record inserted successfully into Person table
# 430000 Record inserted successfully into Person table
# 435000 Record inserted successfully into Person table
# 440000 Record inserted successfully into Person table
# ...
# 535000 Record inserted successfully into Person table
# 540000 Record inserted successfully into Person table
# 545000 Record inserted successfully into Person table
# 550000 Record inserted successfully into Person table
# 555000 Record inserted successfully into Person table
# 560000 Record inserted successfully into Person table
# 565000 Record inserted successfully into Person table
# 570000 Record inserted successfully into Person table
# 575000 Record inserted successfully into Person table
# 580000 Record inserted successfully into Person table
# 585000 Record inserted successfully into Person table
# 590000 Record inserted successfully into Person table
# 595000 Record inserted successfully into Person table
# 600000 Record inserted successfully into Person table
# 605000 Record inserted successfully into Person table
# 610000 Record inserted successfully into Person table
# 615000 Record inserted successfully into Person table
# 620000 Record inserted successfully into Person table
# 625000 Record inserted successfully into Person table
# 630000 Record inserted successfully into Person table
# 635000 Record inserted successfully into Person table
# 640000 Record inserted successfully into Person table
# 645000 Record inserted successfully into Person table
# 650000 Record inserted successfully into Person table
# 655000 Record inserted successfully into Person table
# 660000 Record inserted successfully into Person table
# 665000 Record inserted successfully into Person table
# 670000 Record inserted successfully into Person table
# 675000 Record inserted successfully into Person table
# 680000 Record inserted successfully into Person table
# 685000 Record inserted successfully into Person table
# 690000 Record inserted successfully into Person table
# 695000 Record inserted successfully into Person table
# 700000 Record inserted successfully into Person table
# 705000 Record inserted successfully into Person table
# 710000 Record inserted successfully into Person table
# 715000 Record inserted successfully into Person table
# 720000 Record inserted successfully into Person table
# 725000 Record inserted successfully into Person table
# 730000 Record inserted successfully into Person table
# 735000 Record inserted successfully into Person table
# 740000 Record inserted successfully into Person table
# 745000 Record inserted successfully into Person table
# 750000 Record inserted successfully into Person table
# 755000 Record inserted successfully into Person table
# 760000 Record inserted successfully into Person table
# 765000 Record inserted successfully into Person table
# 770000 Record inserted successfully into Person table
# 775000 Record inserted successfully into Person table
# 780000 Record inserted successfully into Person table
# 785000 Record inserted successfully into Person table
# 790000 Record inserted successfully into Person table
# 795000 Record inserted successfully into Person table
# 800000 Record inserted successfully into Person table
# 805000 Record inserted successfully into Person table
# 810000 Record inserted successfully into Person table
# 815000 Record inserted successfully into Person table
# 820000 Record inserted successfully into Person table
# 825000 Record inserted successfully into Person table
# 830000 Record inserted successfully into Person table
# 835000 Record inserted successfully into Person table
# 840000 Record inserted successfully into Person table
# 845000 Record inserted successfully into Person table
# 850000 Record inserted successfully into Person table
# 855000 Record inserted successfully into Person table
# 860000 Record inserted successfully into Person table
# 865000 Record inserted successfully into Person table
# 870000 Record inserted successfully into Person table
# 875000 Record inserted successfully into Person table
# 880000 Record inserted successfully into Person table
# 885000 Record inserted successfully into Person table
# 890000 Record inserted successfully into Person table
# 895000 Record inserted successfully into Person table
# 900000 Record inserted successfully into Person table
# 905000 Record inserted successfully into Person table
# 910000 Record inserted successfully into Person table
# 915000 Record inserted successfully into Person table
# 920000 Record inserted successfully into Person table
# 925000 Record inserted successfully into Person table
# 930000 Record inserted successfully into Person table
# 935000 Record inserted successfully into Person table
# 940000 Record inserted successfully into Person table
# 945000 Record inserted successfully into Person table
# 950000 Record inserted successfully into Person table
# 955000 Record inserted successfully into Person table
# 960000 Record inserted successfully into Person table
# 965000 Record inserted successfully into Person table
# 970000 Record inserted successfully into Person table
# 975000 Record inserted successfully into Person table
# 980000 Record inserted successfully into Person table
# 985000 Record inserted successfully into Person table
# 990000 Record inserted successfully into Person table
# 995000 Record inserted successfully into Person table
# 1000000 Record inserted successfully into Person table
# MySQL connection is closed
# 5000 Record inserted successfully into Person table
# 10000 Record inserted successfully into Person table
# 15000 Record inserted successfully into Person table
# 20000 Record inserted successfully into Person table
# 25000 Record inserted successfully into Person table
# 30000 Record inserted successfully into Person table
# 35000 Record inserted successfully into Person table
# 40000 Record inserted successfully into Person table
# 45000 Record inserted successfully into Person table
# 50000 Record inserted successfully into Person table
# 55000 Record inserted successfully into Person table
# 60000 Record inserted successfully into Person table
# 65000 Record inserted successfully into Person table
# 70000 Record inserted successfully into Person table
# 75000 Record inserted successfully into Person table
# 80000 Record inserted successfully into Person table
# 85000 Record inserted successfully into Person table
# 90000 Record inserted successfully into Person table
# 95000 Record inserted successfully into Person table
# 100000 Record inserted successfully into Person table
# 105000 Record inserted successfully into Person table
# 110000 Record inserted successfully into Person table
# 115000 Record inserted successfully into Person table
# 120000 Record inserted successfully into Person table
# 125000 Record inserted successfully into Person table
# 130000 Record inserted successfully into Person table
# 135000 Record inserted successfully into Person table
# 140000 Record inserted successfully into Person table
# 145000 Record inserted successfully into Person table
# 150000 Record inserted successfully into Person table
# 155000 Record inserted successfully into Person table
# 160000 Record inserted successfully into Person table
# 165000 Record inserted successfully into Person table
# 170000 Record inserted successfully into Person table
# 175000 Record inserted successfully into Person table
# 180000 Record inserted successfully into Person table
# 185000 Record inserted successfully into Person table
# 190000 Record inserted successfully into Person table
# 195000 Record inserted successfully into Person table
# 200000 Record inserted successfully into Person table
# 205000 Record inserted successfully into Person table
# 210000 Record inserted successfully into Person table
# 215000 Record inserted successfully into Person table
# 220000 Record inserted successfully into Person table
# 225000 Record inserted successfully into Person table
# 230000 Record inserted successfully into Person table
# 235000 Record inserted successfully into Person table
# 240000 Record inserted successfully into Person table
# 245000 Record inserted successfully into Person table
# 250000 Record inserted successfully into Person table
# 255000 Record inserted successfully into Person table
# 260000 Record inserted successfully into Person table
# 265000 Record inserted successfully into Person table
# 270000 Record inserted successfully into Person table
# 275000 Record inserted successfully into Person table
# 280000 Record inserted successfully into Person table
# 285000 Record inserted successfully into Person table
# 290000 Record inserted successfully into Person table
# 295000 Record inserted successfully into Person table
# 300000 Record inserted successfully into Person table
# 305000 Record inserted successfully into Person table
# 310000 Record inserted successfully into Person table
# 315000 Record inserted successfully into Person table
# 320000 Record inserted successfully into Person table
# 325000 Record inserted successfully into Person table
# 330000 Record inserted successfully into Person table
# 335000 Record inserted successfully into Person table
# 340000 Record inserted successfully into Person table
# 345000 Record inserted successfully into Person table
# 350000 Record inserted successfully into Person table
# 355000 Record inserted successfully into Person table
# 360000 Record inserted successfully into Person table
# 365000 Record inserted successfully into Person table
# 370000 Record inserted successfully into Person table
# 375000 Record inserted successfully into Person table
# 380000 Record inserted successfully into Person table
# 385000 Record inserted successfully into Person table
# 390000 Record inserted successfully into Person table
# 395000 Record inserted successfully into Person table
# 400000 Record inserted successfully into Person table
# 405000 Record inserted successfully into Person table
# 410000 Record inserted successfully into Person table
# 415000 Record inserted successfully into Person table
# 420000 Record inserted successfully into Person table
# 425000 Record inserted successfully into Person table
# 430000 Record inserted successfully into Person table
# 435000 Record inserted successfully into Person table
# 440000 Record inserted successfully into Person table
# 445000 Record inserted successfully into Person table
# 450000 Record inserted successfully into Person table
# 455000 Record inserted successfully into Person table
# 460000 Record inserted successfully into Person table
# 465000 Record inserted successfully into Person table
# 470000 Record inserted successfully into Person table
# 475000 Record inserted successfully into Person table
# 480000 Record inserted successfully into Person table
# 485000 Record inserted successfully into Person table
# 490000 Record inserted successfully into Person table
# 495000 Record inserted successfully into Person table
# 500000 Record inserted successfully into Person table
# 505000 Record inserted successfully into Person table
# 510000 Record inserted successfully into Person table
# 515000 Record inserted successfully into Person table
# 520000 Record inserted successfully into Person table
# 525000 Record inserted successfully into Person table
# 530000 Record inserted successfully into Person table
# 535000 Record inserted successfully into Person table
# 540000 Record inserted successfully into Person table
# 545000 Record inserted successfully into Person table
# 550000 Record inserted successfully into Person table
# 555000 Record inserted successfully into Person table
# 560000 Record inserted successfully into Person table
# 565000 Record inserted successfully into Person table
# 570000 Record inserted successfully into Person table
# 575000 Record inserted successfully into Person table
# 580000 Record inserted successfully into Person table
# 585000 Record inserted successfully into Person table
# 590000 Record inserted successfully into Person table
# 595000 Record inserted successfully into Person table
# 600000 Record inserted successfully into Person table
# 605000 Record inserted successfully into Person table
# 610000 Record inserted successfully into Person table
# 615000 Record inserted successfully into Person table
# 620000 Record inserted successfully into Person table
# 625000 Record inserted successfully into Person table
# 630000 Record inserted successfully into Person table
# 635000 Record inserted successfully into Person table
# 640000 Record inserted successfully into Person table
# 645000 Record inserted successfully into Person table
# 650000 Record inserted successfully into Person table
# 655000 Record inserted successfully into Person table
# 660000 Record inserted successfully into Person table
# 665000 Record inserted successfully into Person table
# 670000 Record inserted successfully into Person table
# 675000 Record inserted successfully into Person table
# 680000 Record inserted successfully into Person table
# 685000 Record inserted successfully into Person table
# 690000 Record inserted successfully into Person table
# 695000 Record inserted successfully into Person table
# 700000 Record inserted successfully into Person table
# 705000 Record inserted successfully into Person table
# 710000 Record inserted successfully into Person table
# 715000 Record inserted successfully into Person table
# 720000 Record inserted successfully into Person table
# 725000 Record inserted successfully into Person table
# 730000 Record inserted successfully into Person table
# 735000 Record inserted successfully into Person table
# 740000 Record inserted successfully into Person table
# 745000 Record inserted successfully into Person table
# 750000 Record inserted successfully into Person table
# 755000 Record inserted successfully into Person table
# 760000 Record inserted successfully into Person table
# 765000 Record inserted successfully into Person table
# 770000 Record inserted successfully into Person table
# 775000 Record inserted successfully into Person table
# 780000 Record inserted successfully into Person table
# 785000 Record inserted successfully into Person table
# 790000 Record inserted successfully into Person table
# 795000 Record inserted successfully into Person table
# 800000 Record inserted successfully into Person table
# 805000 Record inserted successfully into Person table
# 810000 Record inserted successfully into Person table
# 815000 Record inserted successfully into Person table
# 820000 Record inserted successfully into Person table
# 825000 Record inserted successfully into Person table
# 830000 Record inserted successfully into Person table
# 835000 Record inserted successfully into Person table
# 840000 Record inserted successfully into Person table
# 845000 Record inserted successfully into Person table
# 850000 Record inserted successfully into Person table
# 855000 Record inserted successfully into Person table
# 860000 Record inserted successfully into Person table
# 865000 Record inserted successfully into Person table
# 870000 Record inserted successfully into Person table
# 875000 Record inserted successfully into Person table
# 880000 Record inserted successfully into Person table
# 885000 Record inserted successfully into Person table
# 890000 Record inserted successfully into Person table
# 895000 Record inserted successfully into Person table
# 900000 Record inserted successfully into Person table
# 905000 Record inserted successfully into Person table
# 910000 Record inserted successfully into Person table
# 915000 Record inserted successfully into Person table
# 920000 Record inserted successfully into Person table
# 925000 Record inserted successfully into Person table
# 930000 Record inserted successfully into Person table
# 935000 Record inserted successfully into Person table
# 940000 Record inserted successfully into Person table
# 945000 Record inserted successfully into Person table
# 950000 Record inserted successfully into Person table
# 955000 Record inserted successfully into Person table
# 960000 Record inserted successfully into Person table
# 965000 Record inserted successfully into Person table
# 970000 Record inserted successfully into Person table
# 975000 Record inserted successfully into Person table
# 980000 Record inserted successfully into Person table
# 985000 Record inserted successfully into Person table
# 990000 Record inserted successfully into Person table
# 995000 Record inserted successfully into Person table
# 1000000 Record inserted successfully into Person table
# MySQL connection is closed
# 37.4 s ± 120 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# !mysql load_testing -e "Select Count(*) from Person"
# Out:
# +----------+
# | Count(*) |
# +----------+
# |  8000000 |
# +----------+

# %%
# !mysql < /home/jupyter/create_table.sql

# %%
# !mysql load_testing -e "select count(*) from Person"
# Out:
# +----------+
# | count(*) |
# +----------+
# |        0 |
# +----------+

# %% [markdown]
# ## Our batch size is 50000

# %%
# %%timeit
import mysql.connector

connection = mysql.connector.connect(
  host="10.128.0.3",
  user="root",
  password="12345",
  database="load_testing",
  autocommit=False
)

#

file = open('us-1000000.csv')
csvreader = csv.reader(file)
header = []
header = next(csvreader)
batch = [] 

insert_stmt = (
  "INSERT INTO Person ( first_name, last_name, company, addresss, city, county, state, postal_code, phone_1, phone_2, email, web) "
  "VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s )"
)
counter = 0 
cursor = connection.cursor()

for row in csvreader:
            
            batch.append(row)
            counter += 1
        
            if len(batch) == 50000:
                
                try:
                    cursor.executemany(insert_stmt, batch)
                    connection.commit()
                    print(counter, "Record inserted successfully into Person table")
                    batch = [] 
    
                except mysql.connector.Error as error:
                            print("Failed to insert record into Person table {}".format(error))

                finally:
                    if counter == 1000000:
                        if connection.is_connected():
                                connection.close()
                                print("MySQL connection is closed")
               
file.close()
# Out:
# 50000 Record inserted successfully into Person table
# 100000 Record inserted successfully into Person table
# 150000 Record inserted successfully into Person table
# 200000 Record inserted successfully into Person table
# 250000 Record inserted successfully into Person table
# 300000 Record inserted successfully into Person table
# 350000 Record inserted successfully into Person table
# 400000 Record inserted successfully into Person table
# 450000 Record inserted successfully into Person table
# 500000 Record inserted successfully into Person table
# 550000 Record inserted successfully into Person table
# 600000 Record inserted successfully into Person table
# 650000 Record inserted successfully into Person table
# 700000 Record inserted successfully into Person table
# 750000 Record inserted successfully into Person table
# 800000 Record inserted successfully into Person table
# 850000 Record inserted successfully into Person table
# 900000 Record inserted successfully into Person table
# 950000 Record inserted successfully into Person table
# 1000000 Record inserted successfully into Person table
# MySQL connection is closed
# 50000 Record inserted successfully into Person table
# 100000 Record inserted successfully into Person table
# 150000 Record inserted successfully into Person table
# 200000 Record inserted successfully into Person table
# 250000 Record inserted successfully into Person table
# 300000 Record inserted successfully into Person table
# 350000 Record inserted successfully into Person table
# 400000 Record inserted successfully into Person table
# 450000 Record inserted successfully into Person table
# 500000 Record inserted successfully into Person table
# 550000 Record inserted successfully into Person table
# 600000 Record inserted successfully into Person table
# 650000 Record inserted successfully into Person table
# 700000 Record inserted successfully into Person table
# 750000 Record inserted successfully into Person table
# 800000 Record inserted successfully into Person table
# 850000 Record inserted successfully into Person table
# 900000 Record inserted successfully into Person table
# 950000 Record inserted successfully into Person table
# 1000000 Record inserted successfully into Person table
# MySQL connection is closed
# 50000 Record inserted successfully into Person table
# 100000 Record inserted successfully into Person table
# 150000 Record inserted successfully into Person table
# 200000 Record inserted successfully into Person table
# 250000 Record inserted successfully into Person table
# 300000 Record inserted successfully into Person table
# 350000 Record inserted successfully into Person table
# 400000 Record inserted successfully into Person table
# 450000 Record inserted successfully into Person table
# 500000 Record inserted successfully into Person table
# 550000 Record inserted successfully into Person table
# 600000 Record inserted successfully into Person table
# 650000 Record inserted successfully into Person table
# 700000 Record inserted successfully into Person table
# 750000 Record inserted successfully into Person table
# 800000 Record inserted successfully into Person table
# 850000 Record inserted successfully into Person table
# 900000 Record inserted successfully into Person table
# 950000 Record inserted successfully into Person table
# 1000000 Record inserted successfully into Person table
# MySQL connection is closed
# 50000 Record inserted successfully into Person table
# 100000 Record inserted successfully into Person table
# 150000 Record inserted successfully into Person table
# 200000 Record inserted successfully into Person table
# 250000 Record inserted successfully into Person table
# 300000 Record inserted successfully into Person table
# 350000 Record inserted successfully into Person table
# 400000 Record inserted successfully into Person table
# 450000 Record inserted successfully into Person table
# 500000 Record inserted successfully into Person table
# 550000 Record inserted successfully into Person table
# 600000 Record inserted successfully into Person table
# 650000 Record inserted successfully into Person table
# 700000 Record inserted successfully into Person table
# 750000 Record inserted successfully into Person table
# 800000 Record inserted successfully into Person table
# 850000 Record inserted successfully into Person table
# 900000 Record inserted successfully into Person table
# 950000 Record inserted successfully into Person table
# 1000000 Record inserted successfully into Person table
# MySQL connection is closed
# 50000 Record inserted successfully into Person table
# 100000 Record inserted successfully into Person table
# 150000 Record inserted successfully into Person table
# 200000 Record inserted successfully into Person table
# 250000 Record inserted successfully into Person table
# 300000 Record inserted successfully into Person table
# 350000 Record inserted successfully into Person table
# 400000 Record inserted successfully into Person table
# 450000 Record inserted successfully into Person table
# 500000 Record inserted successfully into Person table
# 550000 Record inserted successfully into Person table
# 600000 Record inserted successfully into Person table
# 650000 Record inserted successfully into Person table
# 700000 Record inserted successfully into Person table
# 750000 Record inserted successfully into Person table
# 800000 Record inserted successfully into Person table
# 850000 Record inserted successfully into Person table
# 900000 Record inserted successfully into Person table
# 950000 Record inserted successfully into Person table
# 1000000 Record inserted successfully into Person table
# MySQL connection is closed
# 50000 Record inserted successfully into Person table
# 100000 Record inserted successfully into Person table
# 150000 Record inserted successfully into Person table
# 200000 Record inserted successfully into Person table
# 250000 Record inserted successfully into Person table
# 300000 Record inserted successfully into Person table
# 350000 Record inserted successfully into Person table
# 400000 Record inserted successfully into Person table
# 450000 Record inserted successfully into Person table
# 500000 Record inserted successfully into Person table
# 550000 Record inserted successfully into Person table
# 600000 Record inserted successfully into Person table
# 650000 Record inserted successfully into Person table
# 700000 Record inserted successfully into Person table
# 750000 Record inserted successfully into Person table
# 800000 Record inserted successfully into Person table
# 850000 Record inserted successfully into Person table
# 900000 Record inserted successfully into Person table
# 950000 Record inserted successfully into Person table
# 1000000 Record inserted successfully into Person table
# MySQL connection is closed
# 50000 Record inserted successfully into Person table
# 100000 Record inserted successfully into Person table
# 150000 Record inserted successfully into Person table
# 200000 Record inserted successfully into Person table
# 250000 Record inserted successfully into Person table
# 300000 Record inserted successfully into Person table
# 350000 Record inserted successfully into Person table
# 400000 Record inserted successfully into Person table
# 450000 Record inserted successfully into Person table
# 500000 Record inserted successfully into Person table
# 550000 Record inserted successfully into Person table
# 600000 Record inserted successfully into Person table
# 650000 Record inserted successfully into Person table
# 700000 Record inserted successfully into Person table
# 750000 Record inserted successfully into Person table
# 800000 Record inserted successfully into Person table
# 850000 Record inserted successfully into Person table
# 900000 Record inserted successfully into Person table
# 950000 Record inserted successfully into Person table
# 1000000 Record inserted successfully into Person table
# MySQL connection is closed
# 50000 Record inserted successfully into Person table
# 100000 Record inserted successfully into Person table
# 150000 Record inserted successfully into Person table
# 200000 Record inserted successfully into Person table
# 250000 Record inserted successfully into Person table
# 300000 Record inserted successfully into Person table
# 350000 Record inserted successfully into Person table
# 400000 Record inserted successfully into Person table
# 450000 Record inserted successfully into Person table
# 500000 Record inserted successfully into Person table
# 550000 Record inserted successfully into Person table
# 600000 Record inserted successfully into Person table
# 650000 Record inserted successfully into Person table
# 700000 Record inserted successfully into Person table
# 750000 Record inserted successfully into Person table
# 800000 Record inserted successfully into Person table
# 850000 Record inserted successfully into Person table
# 900000 Record inserted successfully into Person table
# 950000 Record inserted successfully into Person table
# 1000000 Record inserted successfully into Person table
# MySQL connection is closed
# 36.3 s ± 141 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# !mysql load_testing -e "Select Count(*) from Person"
# Out:
# +----------+
# | Count(*) |
# +----------+
# |  8000000 |
# +----------+

# %%
# !mysql < /home/jupyter/create_table.sql

# %%
# !mysql load_testing -e "select count(*) from Person"
# Out:
# +----------+
# | count(*) |
# +----------+
# |        0 |
# +----------+

# %% [markdown]
# ## Our batch size is 500000

# %%
# %%timeit
import mysql.connector

connection = mysql.connector.connect(
  host="10.128.0.3",
  user="root",
  password="12345",
  database="load_testing",
  autocommit=False
)

#

file = open('us-1000000.csv')
csvreader = csv.reader(file)
header = []
header = next(csvreader)
batch = [] 

insert_stmt = (
  "INSERT INTO Person ( first_name, last_name, company, addresss, city, county, state, postal_code, phone_1, phone_2, email, web) "
  "VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s )"
)
counter = 0 
cursor = connection.cursor()

for row in csvreader:
            
            batch.append(row)
            counter += 1
        
            if len(batch) == 500000:
                
                try:
                    cursor.executemany(insert_stmt, batch)
                    connection.commit()
                    print(counter, "Record inserted successfully into Person table")
                    batch = [] 
    
                except mysql.connector.Error as error:
                            print("Failed to insert record into Person table {}".format(error))

                finally:
                    if counter == 1000000:
                        if connection.is_connected():
                                connection.close()
                                print("MySQL connection is closed")
               
file.close()
# Out:
# 500000 Record inserted successfully into Person table
# 1000000 Record inserted successfully into Person table
# MySQL connection is closed
# 500000 Record inserted successfully into Person table
# 1000000 Record inserted successfully into Person table
# MySQL connection is closed
# 500000 Record inserted successfully into Person table
# 1000000 Record inserted successfully into Person table
# MySQL connection is closed
# 500000 Record inserted successfully into Person table
# 1000000 Record inserted successfully into Person table
# MySQL connection is closed
# 500000 Record inserted successfully into Person table
# 1000000 Record inserted successfully into Person table
# MySQL connection is closed
# 500000 Record inserted successfully into Person table
# 1000000 Record inserted successfully into Person table
# MySQL connection is closed
# 500000 Record inserted successfully into Person table
# 1000000 Record inserted successfully into Person table
# MySQL connection is closed
# 500000 Record inserted successfully into Person table
# 1000000 Record inserted successfully into Person table
# MySQL connection is closed
# 37.7 s ± 253 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# !mysql load_testing -e "Select Count(*) from Person"
# Out:
# +----------+
# | Count(*) |
# +----------+
# |  8000000 |
# +----------+

# %%
# !mysql < /home/jupyter/create_table.sql
# Out:
# ERROR 2002 (HY000): Can't connect to MySQL server on '10.128.0.3' (115)

# %%
# !mysql load_testing -e "select count(*) from Person"

# %% [markdown]
# ## Running batch insert (500,000 size) and ungraded server to 30 cpus and 120 GB RAM
